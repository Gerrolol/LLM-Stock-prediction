# %%
#compare the two news_sentiment improveemnt?
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("news_with_sentiment.csv")

print(df.head())

# Plot distributions
plt.figure(figsize=(12, 6))
sns.histplot(df['sent_pos'], color='green', label='Positive', kde=True, bins=20)
sns.histplot(df['sent_neg'], color='red', label='Negative', kde=True, bins=20)
sns.histplot(df['sent_neutral'], color='blue', label='Neutral', kde=True, bins=20)
plt.title("Distribution of Sentiment Scores")
plt.xlabel("Sentiment Score")
plt.ylabel("Count")
plt.legend()
plt.tight_layout()
plt.show()

# Print some statistics
print(df[['sent_pos', 'sent_neg', 'sent_neutral']].describe())
# Out:
#                                                title          publishedAt  \
# 0  Asian Stocks Bounce Back After Treasury-led Se...  2025-05-23 03:06:21
# 1  CATL’s Foray Into Europe Shows China’s Tariff ...  2025-05-23 03:05:32
# 2  BYD Dealerships Failing Show Financial Pain in...  2025-05-23 03:05:22
# 3  Summers Slams Trump’s Move Against Harvard as ...  2025-05-23 03:05:22
# 4  Harvard Legal Fight Supercharged by Trump Fore...  2025-05-23 03:05:20
#
#    sent_pos  sent_neg  sent_neutral
# 0  0.802754  0.151630      0.045616
# 1  0.649228  0.010966      0.339805
# 2  0.013870  0.967442      0.018689
# 3  0.031588  0.784693      0.183719
# 4  0.041457  0.788202      0.170342
# --- Summary Statistics ---
#         sent_pos   sent_neg  sent_neutral
# count  99.000000  99.000000     99.000000
# mean    0.256804   0.301841      0.431254
# std     0.302479   0.338558      0.356960
# min     0.000000   0.000000      0.000000
# 25%     0.039892   0.033412      0.075272
# ...
